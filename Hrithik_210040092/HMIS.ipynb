# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('/content/NDAP_REPORT_7068.csv')

# %%
df.head(1)
# Out:
#    Rowid Country  State lgd code              State  District lgd code  \
# 0      1   India               1  Jammu And Kashmir                  1
#
#    District  Yearcode                              Year  \
# 0  Anantnag      2017  Financial Year (Apr - Mar), 2017
#
#    Women registered for ante natal care( anc )  \
# 0                                      27773.0
#
#    Women registered for ante natal care ( anc ) within first trimester  ...  \
# 0                                            25353.0                    ...
#
#    Infant deaths reported  \
# 0                    73.0
#
#    Deaths due to sepsis (to total reported infant deaths) (%)  \
# 0                                                6.8
#
#    Deaths due to asphyxia (to total reported infant deaths) (%)  \
# 0                                               17.8
#
#    Deaths due to pneumonia (to total reported infant deaths ) (%)  \
# 0                                                0.0
#
# ...

# %%
df.shape
# Out:
# (2208, 206)

# %%
#Number of null values
no_null=df.isna().sum()
no_null
# Out:
# Rowid                                                               0
# Country                                                             0
# State lgd code                                                      0
# State                                                               0
# District lgd code                                                   0
#                                                                  ...
# Deaths due to fever to total reported infant deaths (%)            55
# Deaths due to measles ( to total reported infant deaths ) (%)      55
# Institutional deliveries at urban health facilities               454
# Institutional deliveries at district hospitals ( dhs )           2208
# Measles immunisation at urban health facilities                  2208
# Length: 206, dtype: int64

# %%
column_list=df.columns
print(column_list)
# Out:
# Index(['Rowid', 'Country', 'State lgd code', 'State', 'District lgd code',
#        'District', 'Yearcode', 'Year',
#        'Women registered for ante natal care( anc )',
#        'Women registered for ante natal care ( anc ) within first trimester',
#        ...
#        'Infant deaths reported',
#        'Deaths due to sepsis (to total reported infant deaths) (%)',
#        'Deaths due to asphyxia (to total reported infant deaths) (%)',
#        'Deaths due to pneumonia (to total reported infant deaths ) (%)',
#        'Deaths due to diarrhea (to total reported infant deaths ) (%)',
#        'Deaths due to fever to total reported infant deaths (%)',
#        'Deaths due to measles ( to total reported infant deaths ) (%)',
#        'Institutional deliveries at urban health facilities',
#        'Institutional deliveries at district hospitals ( dhs )',
#        'Measles immunisation at urban health facilities'],
#       dtype='object', length=206)

# %%
interested_columns = []

for column in column_list:
    c = column.lower()
    words = c.split()
    if not any(word in words for word in ['women', 'child', 'infant', 'infants']):
        interested_columns.append(column)

# %%
for elements in interested_columns:
  print(elements)
print(len(interested_columns))
# Out:
# Rowid
# Country
# State lgd code
# State
# District lgd code
# District
# Yearcode
# Year
# Registrations for ante natal care ( anc ) in the first trimester (to total anc registrations) (%)
# Home deliveries
# Home deliveries attended by doctor or nurse or auxiliary nurse midwife ( anm ) trained as ( sba )
# Home deliveries attended by traditional birth attendants ( tba ) or dai non-trained as skill birth attendants ( sba )
# Home deliveries attended by skilled birth attendants (%)
# Deliveries conducted at public institutions
# Deliveries conducted at private institutions
# Institutional deliveries includes both public and private institutions
# Institutional deliveries (to total anc registrations) (%)
# Total reported deliveries
# Institutional deliveries (to total reported deliveries) (%)
# Safe deliveries (to total reported deliveries) (%)
# Home deliveries (to total reported deliveries) (%)
# Caesarean ( c-section ) deliveries conducted at public facilities
# ...

# %%
interested_df = df[interested_columns]

# %%
interested_df.head(5)
# Out:
#    Rowid Country  State lgd code              State  District lgd code  \
# 0      1   India               1  Jammu And Kashmir                  1
# 1      2   India               1  Jammu And Kashmir                  1
# 2      3   India               1  Jammu And Kashmir                  1
# 3      4   India               1  Jammu And Kashmir                  2
# 4      5   India               1  Jammu And Kashmir                  2
#
#    District  Yearcode                              Year  \
# 0  Anantnag      2017  Financial Year (Apr - Mar), 2017
# 1  Anantnag      2018  Financial Year (Apr - Mar), 2018
# 2  Anantnag      2019  Financial Year (Apr - Mar), 2019
# 3    Budgam      2017  Financial Year (Apr - Mar), 2017
# 4    Budgam      2018  Financial Year (Apr - Mar), 2018
#
#    Registrations for ante natal care ( anc ) in the first trimester (to total anc registrations) (%)  \
# 0                                               91.3
# ...

# %%
interested_df.to_csv('interested_data_NDAP_REPORT_7068.csv', index=False)
